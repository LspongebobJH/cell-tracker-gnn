# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %config InlineBackend.figure_format = 'retina'
# Out:
# /tmp/ipykernel_12655/3277997679.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import cv2

# %%
from PIL import Image
import numpy as np

# %% [markdown]
# # TRA GT

# %%
dire = "/home/ubuntu/cell-tracker-gnn/data/CTC/Training/Fluo-N3DH-CE/01_GT/TRA/"
path = dire + "man_track100.tif"
a = Image.open(path)
Image.fromarray(np.array(a) * 10).show()
# Out:
# <PIL.Image.Image image mode=L size=708x512>

# %%
import multipagetiff as mtif
from matplotlib import pyplot as plt

# %%
dire = "/home/ubuntu/cell-tracker-gnn/data/CTC/Training/Fluo-N3DH-CE/01/"
path = dire + "t000.tif"
s = mtif.read_stack(path, units='um')

# %%
s
# Out:
# Multi-Page Stack of 35 pages. (dx=dy=1um, dz=1um, crop=[0, 512, 0, 708]], page limits=[0, 35])

# %%
mtif.plot_pages(s)

# %%
Image.fromarray(s[16]).show()
# Out:
# <PIL.Image.Image image mode=L size=708x512>

# %%
dire = "/home/ubuntu/cell-tracker-gnn/data/CTC/Training/Fluo-N3DH-CE/01_GT/TRA/"
path = dire + "man_track000.tif"
s = mtif.read_stack(path, units='um')

# %%
s
# Out:
# Multi-Page Stack of 35 pages. (dx=dy=1um, dz=1um, crop=[0, 512, 0, 708]], page limits=[0, 35])

# %%
mtif.plot_pages(s)

# %%
Image.fromarray(s[19] *1000).show()
# Out:
# <PIL.Image.Image image mode=L size=708x512>

# %%
np.unique(s[16])
# Out:
# array([  0,   6,  21,  28,  76, 100, 107, 122, 140, 324, 339, 346, 370,
#        410, 434, 611, 618, 626, 633, 664, 695], dtype=uint16)

# %%
(s[16] == 100).sum()
# Out:
# 25

# %% [markdown]
# # SEG GT

# %%
dire = "/home/ubuntu/cell-tracker-gnn/data/CTC/Training/Fluo-N2DH-SIM+/01_GT/SEG/"
path = dire + "man_seg020.tif"
a = Image.open(path)
a.show()
Image.fromarray(np.array(a) * 10).show()
# Out:
# <PIL.Image.Image image mode=L size=628x690>
# <PIL.Image.Image image mode=L size=628x690>

# %%
dire = "/home/ubuntu/cell-tracker-gnn/data/CTC/Training/Fluo-N2DH-SIM+/01/"
path = dire + "t000.tif"
a = Image.open(path)
a.show()
# Out:
# <PIL.Image.Image image mode=L size=628x690>
